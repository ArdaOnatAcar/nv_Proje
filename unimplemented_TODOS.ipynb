# %% [markdown]
# ### Done
# 1) Personel hizmet eşleştirme kısmında personeller eklenecek hizmetler eklenecek eşleşme kısmı en altta olacak, atamalara ait kaydet butonları kaldırılacak.
# 2) İşletmeler işletme kaydında boş yer bırakmadan işletmeyi doldurmalı ve en son kaydet butonuna basmalı.
# 3) Bir personel 2 farklı hizmet verirken diğer personel 1 hizmet verebiliyor olsun. Daima az hizmet verebilen personeli öncelikli atayalım. Bu durumda fazla hizmete randevu kapanmamış olur..
# 4) MHRS mantığıyla şehir seçimi hem işletme oluşturmaya(dolayısıyla işletme verisine yeni attribute geldi) hem de randevu ararken filtre kısmına eklenecek.
# 5) İlk uygulama açıldığında en son kaldığımız yerden açılıyor. Mesela ben logged in bir şekildeyken uygulamayı kapattığımda, geri açtığımda yine logged in bir şekilde devam ediyor. Burada uygulama açıldığında direkt login sayfası açılması lazım
# 6) Müşteri randevularım sekmesindeki randevuların tarihi geçince gray-out olsun. Yanında tarihi geçti yazsın.
# 7) Müşteri randevularının tarihi geçtikten 30 gün sonra o randevu, randevularım kısmından silinsin.
# 8) Müşteriler için favorilerim(ya da yer işaretlerim) eklensin. Böylelikle her defasında aynı yere randevu alan müşterilere kolaylık olsun
# 9) İşletmelerin randevularım kısmında tarihi geçen randevular gray-out olsun. Randevu tarihi geçtikten 1 gün sonra işletme randevularım listesinden kaldırılır; tamamlandı butonu kaldırıldı.
# 10) İşletmelerim kısmında işletme bilgileri (adres, açıklama, açılış-kapanış vb.) düzenlenebilir hale getirildi.
# 11) “Yeni işletme ekle” ve “Yeni randevu ekle” butonlarının genişliği azaltıldı (compact).

# %% [markdown]
# ##### TODO
#
# 12) Yorumlar eklenecek. Yorumun eklenebilmesi için randevu onaylanmış ve randevu tarihi geçmiş olmalı. Müşteriler randevularım kısmında gray_out olan randevularının altında küçük bir yorumla butonu görecek. Buraya 1-5 puan verecek ve açıklama yazacak. İşletmelerin altında da ortalama puanları ve yorum sayıları gözükecek.
# 13) İşletmeler yorum sayısı, ortalama puana göre sıralanabilecek.
# 14) İşletmeler yorum sayısına göre filtrelenebilecek (0-50, 50-200, 200+)
# 15) İşletmeler ortalama puana göre filtrelenebilecek (+4,5,+4,+3)
